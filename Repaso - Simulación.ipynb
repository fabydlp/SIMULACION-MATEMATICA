# %% [markdown]
# # Repaso - Módulo 2

# %% [markdown]
# ---
# ## Problema 1.1. Evaluación numérica de integrales utilizando Montecarlo
# Escriba la función para integrar por el método Montecarlo de tipo 1

# %% [markdown]
# *valor promedio* de una función y en el *valor esperado* de una *variable aleatoria uniforme*.

# %% [markdown]
# $$A(\mathcal{D})=\int_{a}^{b}y\text{d}x.$$

# %% [markdown]
# Considere las funciones $f_1(x)=\sqrt{1+x^{4}}$, $f_2(x)=\ln(\ln x)$, $f_3(x)=\frac {1}{\ln x}$, y $f_4(x)=e^{-{\frac {x^{2}}{2}}}$.
#
# Utilizar la función anterior para realizar la evaluación numérica de las integrales de las funciones anteriores en el intervalo $(4,5)$. Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y cuyas columnas correspondan a las funciones.

# %% [markdown]
# 1. $f_1(x)=\sqrt{1+x^{4}}$

# %%
import numpy as np
def f(x):
    
    return np.sqrt(1+x**4)


N = 100000
# np.random.seed (0)
u = np.random.uniform(4,5,N) 
np.mean(f(u))*(5-4)
# Out:
# 20.347304050035813

# %%
import pandas as pd
N = np.logspace(1,5,5) #5 terminos
table1 = pd.DataFrame(columns=["Aproximación", "Error"], index=N)

def montecarlo(f, N, a, b):
    u = np.random.uniform(a, b, N)
    return np.mean(f(u))*(b-a)

for i in N:
    table1.loc[i, "Aproximación"] = montecarlo(f, int(i), 4, 5)
    
table1["Error"] = np.abs(20.3583 - table1 ["Aproximación"]) 
table1
# Out:
#          Aproximación     Error
# 10.0        21.583764  1.225464
# 100.0       20.271173  0.087127
# 1000.0      20.404963  0.046663
# 10000.0     20.344737  0.013563
# 100000.0    20.359664  0.001364

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([2, 3, 4, 5, 6], table1["Error"])

# %% [markdown]
# 2. $f_2(x)=\ln(\ln x)$

# %%
import numpy as np
def f(x):
    
    return np.log(np.log(x))


N = 100000
# np.random.seed (0)
u = np.random.uniform(4,5,N) 
np.mean(f(u))*(5-4)
# Out:
# 0.40576347442657273

# %%
import pandas as pd
N = np.logspace(1,5,5) #5 terminos
table2 = pd.DataFrame(columns=["Aproximación", "Error"], index=N)

def montecarlo(f, N, a, b):
    u = np.random.uniform(a, b, N)
    return np.mean(f(u))*(b-a)

for i in N:
    table2.loc[i, "Aproximación"] = montecarlo(f, int(i), 4, 5)
    
table2["Error"] = np.abs(0.405885 - table2 ["Aproximación"]) 
table2
# Out:
#          Aproximación     Error
# 10.0         0.419222  0.013337
# 100.0        0.412095   0.00621
# 1000.0       0.406835   0.00095
# 10000.0      0.406155   0.00027
# 100000.0     0.405986  0.000101

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([2, 3, 4, 5, 6], table2["Error"])

# %% [markdown]
# 3. $f_3(x)=\frac {1}{\ln x}$

# %%
import numpy as np
def f(x):
    
    return 1/np.log(x)


N = 100000
# np.random.seed (0)
u = np.random.uniform(4,5,N) 
np.mean(f(u))*(5-4)
# Out:
# 0.6671312805415404

# %%
import pandas as pd
N = np.logspace(1,5,5) #5 terminos
table3 = pd.DataFrame(columns=["Aproximación", "Error"], index=N)

def montecarlo(f, N, a, b):
    u = np.random.uniform(a, b, N)
    return np.mean(f(u))*(b-a)

for i in N:
    table3.loc[i, "Aproximación"] = montecarlo(f, int(i), 4, 5)
    
table3["Error"] = np.abs(0.667003 - table3 ["Aproximación"]) 
table3
# Out:
#          Aproximación     Error
# 10.0         0.660803    0.0062
# 100.0        0.664126  0.002877
# 1000.0        0.66712  0.000117
# 10000.0       0.66716  0.000157
# 100000.0     0.666949  0.000054

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([2, 3, 4, 5, 6], table3["Error"])

# %% [markdown]
# 4. $f_4(x)=e^{-{\frac {x^{2}}{2}}}$

# %%
import numpy as np
def f(x):
    
    return np.exp(-(x**2)/2)


N = 100000
# np.random.seed (0)
u = np.random.uniform(4,5,N) 
np.mean(f(u))*(5-4)
# Out:
# 7.867586078163191e-05

# %%
import pandas as pd
N = np.logspace(1,5,5) #5 terminos
table4 = pd.DataFrame(columns=["Aproximación", "Error"], index=N)

def montecarlo(f, N, a, b):
    u = np.random.uniform(a, b, N)
    return np.mean(f(u))*(b-a)

for i in N:
    table4.loc[i, "Aproximación"] = montecarlo(f, int(i), 4, 5)
    
table4["Error"] = np.abs(0.0000786695 - table4 ["Aproximación"]) 
table4
# Out:
#          Aproximación     Error
# 10.0         0.000052  0.000027
# 100.0        0.000072  0.000007
# 1000.0        0.00008  0.000001
# 10000.0      0.000078  0.000001
# 100000.0     0.000078       0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([2, 3, 4, 5, 6], table4["Error"])

# %% [markdown]
# ## Problema 1.2.
# Aproximar el área de la región descrita por
#
# $$x^2+2y^2\leq-2x+8y-7$$
#
# Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y en las columnas el valor de aproximación y el error de integración.
#
# Definir unos límites adecuados $a_1$, $b_1$, $a_2$ y $b_2$, para la región $R=\left[a_1,b_1\right]\times\left[a_2,b_2\right]$ y grafíque esta región.

# %%
N = np.logspace(1,5,5)
def montecarlo2(region, a1, b1, a2, b2, N) :
    x = np.random.uniform(a1, b1, N)
    y = np.random.uniform(a2, b2, N)
    B = region(x,y)
    AR = (b1-a1)*(b2-a2)
    return np.mean(B)*AR

def region(x,y):
    return (x**2+2*y**2) <= (-2**x+8*y-7)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.random.uniform(-1,1,100)
y = np.random.uniform(1.5,2.5,100)
X,Y = np.meshgrid(x,y)

plt.figure()
plt.scatter(X,Y, c=~region(X,Y))

# %%
table = pd.DataFrame(columns = ["Aproximación","Error relativo"], index = N)
for i in N:
    table.loc[i,"Aproximación"]= montecarlo2(region,-1,1,1.5,2.5,int(i))
    
ax = -1
bx = 1
ay = 1.5
by = 2.5

AR = (bx-ax)*(by-ay)
for i in N:
    AD = table["Aproximación"][i]
    z= np.sqrt((1-(AD/AR))/(AD/AR))
    table["Error relativo"][i] = z
    
table
# Out:
#          Aproximación Error relativo
# 10.0              0.2            3.0
# 100.0            0.18       3.179797
# 1000.0          0.208       2.935198
# 10000.0        0.2028         2.9769
# 100000.0      0.19818       3.015267

# %% [markdown]
# ---
# ## Problema 2. Fractal aleatorio tipo Barnsley
#
# - En la clase de fractales aleatorios vimos que el fractal helecho de Barnsley se generaba a través de cuatro transformaciones afines que se elegían con cierta probabilidad.
# - Vimos que este helecho representaba de manera muy aproximada helechos reales.
# - Vimos que modificando parámetros de la tabla, se podían generar mutaciones de el helecho.
#
# Pues bien, usando la misma idea de transformaciones afines que se escogen con cierta probabilidad, se pueden generar una infinidad inimaginable de fractales. Incluso, se pueden generar fractales aleatorios que poseen un atractor determinístico.
#
# **Referencia:**
# - Barnsley, Michael F. *Fractals Everywhere: New Edition*, ISBN: 9780486320342.

# %% [markdown]
# Usando la siguiente tabla, evalúe el fractal de Barnsley para 100 000 puntos.

# %%
import pandas as pd
import numpy as np

# %%
i = np.arange(4)

df = pd.DataFrame(index=i,columns=['$ai$', '$bi$', '$ci$', '$di$', '$ei$', '$fi$', '$pi$'], dtype='float')
df.index.name = "$i$"

df['$ai$'] = [0.5, 0.5, 0.5, 0.5]
df['$bi$'] = [0.0, 0.0, 0.0, 0.0]
df['$ci$'] = [0.0, 0.0, 0.0, 0.0]
df['$di$'] = [0.5, 0.5, 0.5, 0.5]
df['$ei$'] = [1.0, 50.0, 1.0, 50.0]
df['$fi$'] = [1.0, 1.0, 50.0, 50.0]
df['$pi$'] = [0.1, 0.2, 0.3, 0.4]

df.round(2)
# Out:
#      $ai$  $bi$  $ci$  $di$  $ei$  $fi$  $pi$
# $i$
# 0     0.5   0.0   0.0   0.5   1.0   1.0   0.1
# 1     0.5   0.0   0.0   0.5  50.0   1.0   0.2
# 2     0.5   0.0   0.0   0.5   1.0  50.0   0.3
# 3     0.5   0.0   0.0   0.5  50.0  50.0   0.4

# %%
import random
random.seed(100000)

x = [0]
y = [0]

for k in range (10**4):
    i_actual = random.choices(i, weights=df['$pi$'])
    
    a = float(df['$ai$'][i_actual])
    b = float(df['$bi$'][i_actual])
    c = float(df['$ci$'][i_actual])
    d = float(df['$di$'][i_actual])
    e = float(df['$ei$'][i_actual])
    f = float(df['$fi$'][i_actual])
    
    xkm1 = a*x[-1] + b*y[-1] + e
    ykm1 = c*x[-1] + d*y[-1] + f
    
    x.append(xkm1)
    y.append(ykm1)

# %%
plt.figure(figsize=(7,10))
plt.scatter(x, y, s=10, c="m")

# %% [markdown]
# ---
# ## Problema 3. Probabilidad Precio-Umbral
#
# En las últimas clases vimos una aplicación de simulación montecarlo. Consistía en descargar datos históricos de precio de cierre de acciones de alguna compañía, proyectar esos precios y sacar la probabilidad de que los precios en el siguiente año sobrepasaran cierto precio umbral.
#
# En este ejemplo evaluaremos dos compañías con tendencias más o menos similares (Apple y Microsoft) veremos cuál tiene más probabilidades de darnos un interés deseado.
#
# Además, descargaremos los datos del año 2020 para ver si el análisis concuerda.

# %% [markdown]
# Descargue datos para Apple y Microsoft desde enero de 2015 a diciembre de 2019 y muestre sus gráficas.

# %%
import pandas_datareader.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

def getClose(name, start, end):
    return web.DataReader(name, "yahoo", start, end)["Adj Close"]

names = ["AAPL", "MSFT"]
data = getClose(names, "2015-01-01", "2019-12-31")
data
# Out:
# Symbols          AAPL        MSFT
# Date
# 2015-01-02  24.644018   40.926445
# 2015-01-05  23.949759   40.550095
# 2015-01-06  23.952009   39.954922
# 2015-01-07  24.287867   40.462563
# 2015-01-08  25.221069   41.652897
# ...               ...         ...
# 2019-12-24  69.738724  153.433258
# 2019-12-26  71.122353  154.690918
# 2019-12-27  71.095390  154.973633
# 2019-12-30  71.517326  153.638000
# 2019-12-31  72.039871  153.745209
#
# [1258 rows x 2 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Calcule los rendimientos diarios junto con sus características estadísticas

# %%
data.shift()
R = (data- data.shift())/(data.shift())
R.describe()
# Out:
# Symbols         AAPL         MSFT
# count    1257.000000  1257.000000
# mean        0.000976     0.001161
# std         0.015646     0.014686
# min        -0.099608    -0.092533
# 25%        -0.005857    -0.005401
# 50%         0.000893     0.000868
# 75%         0.008918     0.008053
# max         0.070421     0.104522

# %%
R.plot()
R.hist()
# Out:
# array([[<AxesSubplot:title={'center':'AAPL'}>,
#         <AxesSubplot:title={'center':'MSFT'}>]], dtype=object)

# %% [markdown]
# Simule 1000 escenarios de rendimientos diarios para el 2020 (para cada una de las empresas)

# %%
data1= getClose("AAPL", "2015-01-01", "2019-12-31")
r = np.log(data1/data1.shift())

def sim_r1(media, std, inicio, dias, N) :
    r = np.random.normal(media, std, size=(dias, N)) #simula tantos dias N veces de una distribución normal
    fechas = pd.date_range(inicio, periods=dias)
    return pd.DataFrame(index = fechas, data = r)
sim_r1(r.mean(), r.std(), "2020-01-01", 365, 1000)
# Out:
#                  0         1         2         3         4         5    \
# 2020-01-01 -0.029559  0.010781 -0.007702 -0.014519 -0.009209  0.026576
# 2020-01-02 -0.005642 -0.003457  0.010338  0.009381 -0.018413 -0.008319
# 2020-01-03 -0.006390 -0.017066  0.017509 -0.016892  0.000725  0.000840
# 2020-01-04 -0.006416  0.013444  0.000965 -0.010554  0.015051  0.001155
# 2020-01-05  0.023198  0.006048 -0.008378 -0.003558 -0.001168 -0.020351
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-26  0.001494 -0.007673 -0.016724 -0.003268  0.028025  0.023383
# 2020-12-27  0.020977  0.003032 -0.008963 -0.010210 -0.002595  0.003436
# 2020-12-28  0.020761 -0.013308 -0.018536  0.013517  0.002763 -0.010688
# 2020-12-29  0.007822 -0.004593  0.006618 -0.017045  0.009654 -0.030773
# 2020-12-30  0.023087  0.008783 -0.003835 -0.006811 -0.003102  0.026123
#
#                  6         7         8         9    ...       990       991  \
# 2020-01-01  0.018909 -0.002808  0.009679 -0.020700  ...  0.009357  0.005402
# 2020-01-02 -0.022335 -0.011562 -0.001542 -0.017028  ...  0.000997 -0.006376
# 2020-01-03 -0.013891  0.006352 -0.018215  0.002615  ...  0.029359 -0.015800
# 2020-01-04 -0.004347  0.015871  0.021844 -0.033327  ...  0.008562  0.021371
# 2020-01-05  0.003273  0.009625 -0.005586 -0.006210  ... -0.006455  0.009532
# ...              ...       ...       ...       ...  ...       ...       ...
# 2020-12
True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Finalmente, grafique los datos reales del 2020 para ver que tan acertado fue nuestro análisis.

# %%
names = ["AAPL", "MSFT"]
data = getClose(names, "2020-01-01", "2020-12-31")
data.plot()
plt.plot(np.asarray(a)[:, 483])
plt.plot(b.mean(axis=1))

# %%
a.shape
# Out:
# (365, 1000)

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
np.asarray(a)[:, 483]
# Out:
# array([ 71.37954273,  70.58766354,  70.12718819,  69.03347235,
#         68.06870353,  67.32889517,  68.25990591,  69.39502061,
#         70.78865986,  71.82692586,  72.69260095,  72.79543493,
#         73.55763014,  74.31531996,  73.64527813,  75.00885642,
#         75.78171918,  75.94386959,  74.16007796,  73.96719691,
#         74.129242  ,  73.89129714,  71.19005834,  71.07070056,
#         72.32499069,  71.79346162,  73.45635297,  73.81527744,
#         73.94859814,  72.23086203,  73.46798494,  74.03950969,
#         75.85535833,  74.57705355,  73.65424579,  72.76421159,
#         72.12560776,  73.77153303,  74.7404475 ,  75.64437198,
#         77.02251913,  78.98371618,  80.20529114,  79.02238122,
#         81.12762389,  79.64103642,  82.39344362,  85.87971986,
#         86.92164849,  87.68170061,  88.01314086,  88.25691483,
#         88.44608058,  89.55026953,  89.18679024,  88.59818503,
#         91.84153291,  93.20385407,  95.00067336,  94.13318423,
#         92.77048297,  94.474681  ,  94.66551189,  96.22182678,
#         96.32571777,  96.13266595,  98.26570651,  97.46055089,
#         97.95812244,  95.64237908,  95.90425977,  95.02364128,
#         94.61742347,  95.73548571,  96.67859534,  99.64401505,
#         98.32392341, 102.16399714, 101.579043  , 101.2111482 ,
#         99.92048373, 101.25519678, 101.76999306, 103.15578386,
#        102.46138214, 102.7447069 , 100.17142153, 101.96903001,
#        101.05498462, 100.86954106, 100.97976798, 100.05244323,
#        100.43718488, 103.33637898, 104.22513699, 107.27163354,
#        105.50156608, 105.90558988, 106.95331997, 106.65068665,
#        104.59953512, 105.50332379, 105.16844716, 105.15788309,
#        103.16556458, 103.97163372, 106.65614801, 106.18859095,
#        103.9419223 , 106.09599042, 107.73808663, 106.12251479,
#        106.75255115, 109.2576825 , 114.7600895 , 116.05082068,
#        116.0393945 , 114.67956263, 114.58075126, 117.19003274,
#        114.82140221, 116.02350775, 117.4676914 , 119.34020598,
#        117.40223893, 118.26532567, 121.11839097, 119.35338207,
#        119.55967443, 120.10915618, 124.20968263, 123.28221567,
#        125.99755349, 125.06778316, 123.51341916, 123.23678939,
#        122.90464205, 121.86074706, 121.26005469, 120.8892258 ,
#        121.29192927, 120.27177712, 120.92373642, 121.8831558 ,
#        122.54350319, 124.61470105, 126.77509633, 124.81262595,
#        124.70734235, 126.12171658, 127.48130847, 126.59367223,
#        127.86955853, 128.62718165, 128.84470046, 129.2238926 ,
#        130.96677906, 128.91324744, 132.18425561, 132.29572753,
#        136.53996424, 136.1351767 , 136.79454859, 139.13613402,
